# %% [markdown]
# Predicting the NBA MVP: Machine Learning Project [part 3 of 3]
#
# * Reading the data into Pandas and cleaning it

# %%
import pandas as pd

# %%
stats = pd.read_csv("player_mvp_stats.csv")

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 14087       14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 14088       14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 14089       14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 14090       14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 14091       14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
#        Pts Max  Share                Team   W   L   W/L%   GB   PS/G   PA/G  \
# 0          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 1          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 2          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 3          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# 4          0.0    0.0  Los Angeles Lakers  58  24  0.707  5.0  106.3   99.6
# ...        ...    ...                 ...  ..  ..    ...  ...    ...    ...
# 14087      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14088      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14089      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14090      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
# 14091      0.0    0.0     Milwaukee Bucks  42  40  0.512  9.0  103.6  103.8
#
#         SRS
# 0      6.73
# 1      6.73
# 2      6.73
# 3      6.73
# 4      6.73
# ...     ...
# 14087 -0.45
# 14088 -0.45
# 14089 -0.45
# 14090 -0.45
# 14091 -0.45
#
# [14092 rows x 42 columns]

# %% [markdown]
# Column deletion Unnamed: 0

# %%
del stats["Unnamed: 0"]

# %% [markdown]
# Machine learning algorithms don't like to use null or missing values

# %%
pd.isnull(stats)
# Out:
#        Player    Pos    Age     Tm      G     GS     MP     FG    FGA    FG%  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14087   False  False  False  False  False  False  False  False  False  False
# 14088   False  False  False  False  False  False  False  False  False  False
# 14089   False  False  False  False  False  False  False  False  False  False
# 14090   False  False  False  False  False  False  False  False  False  False
# 14091   False  False  False  False  False  False  False  False  False  False
#
#        ...  Pts Max  Share   Team      W      L   W/L%     GB   PS/G   PA/G  \
# 0      ...    False  False  False  False  False  False  False  False  False
# 1      ...    False  False  False  False  False  False  False  False  False
# 2      ...    False  False  False  False  False  False  False  False  False
# 3      ...    False  False  False  False  False  False  False  False  False
# 4      ...    False  False  False  False  False  False  False  False  False
# ...    ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14087  ...    False  False  False  False  False  False  False  False  False
# 14088  ...    False  False  False  False  False  False  False  False  False
# 14089  ...    False  False  False  False  False  False  False  False  False
# 14090  ...    False  False  False  False  False  False  False  False  False
# 14091  ...    False  False  False  False  False  False  False  False  False
#
#          SRS
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 14087  False
# 14088  False
# 14089  False
# 14090  False
# 14091  False
#
# [14092 rows x 41 columns]

# %% [markdown]
# The SUM() will show the number of nulls in each column

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %% [markdown]
# Selection in the row statistic of columns with percentage of three null points, it probably means that the player did not try

# %%
stats[pd.isnull(stats["3P%"])]
# Out:
#                  Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%  ...  \
# 2        Elden Campbell  PF   22  LAL  52   0   7.3  1.1  2.4  0.455  ...
# 3         Irving Thomas  PF   25  LAL  26   0   4.2  0.7  1.9  0.340  ...
# 18           Jack Haley   C   28  LAL  49   9   8.0  0.6  1.7  0.369  ...
# 20          Keith Owens  SF   22  LAL  20   0   4.0  0.5  1.6  0.281  ...
# 30      Benoit Benjamin   C   28  LAL  59   6  12.8  2.3  4.6  0.491  ...
# ...                 ...  ..  ...  ...  ..  ..   ...  ...  ...    ...  ...
# 14061    Evan Eschmeyer   C   24  NJN  31   5  12.0  1.2  2.3  0.528  ...
# 14062  Gheorghe Mureșan   C   28  NJN  30   2   8.9  1.4  3.0  0.456  ...
# 14064     Jim McIlvaine   C   27  NJN  66  53  15.9  1.0  2.3  0.416  ...
# 14070  Mark Hendrickson  PF   25  NJN  15   0   4.7  0.3  0.5  0.625  ...
# 14071      Michael Cage   C   38  NJN  20   7  12.1  0.6  1.2  0.500  ...
#
#        Pts Max  Share                Team   W   L   W/L%    GB   PS/G   PA/G  \
# 2          0.0    0.0  Los Angeles Lakers  58  24  0.707   5.0  106.3   99.6
# 3          0.0    0.0  Los Angeles Lakers  58  24  0.707   5.0  106.3   99.6
# 18         0.0    0.0  Los Angeles Lakers  43  39  0.524  14.0  100.4  101.5
# 20         0.0    0.0  Los Angeles Lakers  43  39  0.524  14.0  100.4  101.5
# 30         0.0    0.0  Los Angeles Lakers  39  43  0.476  23.0  104.2  105.5
# ...        ...    ...                 ...  ..  ..    ...   ...    ...    ...
# 14061      0.0    0.0     New Jersey Nets  31  51  0.378  21.0   98.0   99.0
# 14062      0.0    0.0     New Jersey Nets  31  51  0.378  21.0   98.0   99.0
# 14064      0.0    0.0     New Jersey Nets  31  51  0.378  21.0   98.0   99.0
# 14070      0.0    0.0     New Jersey Nets  31  51  0.378  21.0   98.0   99.0
# 14071      0.0    0.0     New Jersey Nets  31  51  0.378  21.0   98.0   99.0
#
#         SRS
# 2      6.73
# 3      6.73
# 18    -0.95
# 20    -0.95
# 30    -1.20
# ...     ...
# 14061 -1.18
# 14062 -1.18
# 14064 -1.18
# 14070 -1.18
# 14071 -1.18
#
# [2042 rows x 41 columns]

# %% [markdown]
# Players with 3 point attempts at 0

# %%
stats[pd.isnull(stats["3P%"])][["Player", "3PA"]]
# Out:
#                  Player  3PA
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14061    Evan Eschmeyer  0.0
# 14062  Gheorghe Mureșan  0.0
# 14064     Jim McIlvaine  0.0
# 14070  Mark Hendrickson  0.0
# 14071      Michael Cage  0.0
#
# [2042 rows x 2 columns]

# %%
stats[pd.isnull(stats["FT%"])][["Player", "FTA"]]
# Out:
#                 Player  FTA
# 77          John Coker  0.0
# 92        Jason Sasser  0.0
# 103    Adrian Caldwell  0.0
# 119       Bruno Šundov  0.0
# 158     Jamal Robinson  0.0
# ...                ...  ...
# 13951    Mark McNamara  0.0
# 13979      Luke Zeller  0.0
# 14032      Myron Brown  0.0
# 14054      Malcolm Lee  0.0
# 14088      Steve Novak  0.0
#
# [462 rows x 2 columns]

# %% [markdown]
# This shows us that all those players who had undefined or missing values in free throw percentage, had zero bid attempts.
# So let's replace all these percentages with zero, it's not technically correct, but in this case, if the player has zero percentage on three-point shots, he's not in the race for MVP.

# %% [markdown]
# * Training a Machine Learning Model

# %%
stats = stats.fillna(0)

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %% [markdown]
# All numeric columns will be used in the prediction, except 'Pts Won', 'Pts Max', 'Share', otherwise the algorithm will know what it is trying to predict.
# 'Share' is the percentage of votes the player has won.
# 'Pts Won' is correlated with 'Share', it's just the points earned divided by 'Pts Max'.
#
# - PREDICTORS = Predicted percentage of MVP votes that someone got in a given year.

# %%
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year','W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %% [markdown]
# Test to train data only from before 2021, this gives us MVP data and all player data before year 2021.

# %%
train = stats[stats["Year"] < 2021]

# %%
test = stats[stats["Year"] == 2021]

# %% [markdown]
# Building the first machine learning using ridge regression, a form of linear regression designed to avoid overfitting

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %% [markdown]
# First ML model, using the PREDICTORS columns in the training datasets, to try to predict the share of an MVP vote that someone got and then we actually go ahead and make the predictions.

# %% [markdown]
# reg.fit(train[predictors], train["Share"])

# %%
reg.fit(train[predictors], train["Share"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
predict
#        -2.41552392e-02, -1.35106193e-02,  1.00763055e-01,  8.52632383e-03,
#        -2.58128250e-02,  2.14119215e-02,  2.93730272e-02, -8.32661978e-03,
#        -1.61691080e-03, -2.71101561e-03,  1.25039940e-02,  1.46943061e-02,
#        -2.23458001e-02,  3.83066039e-02,  8.83139397e-04,  2.87587303e-03,
#         5.58366480e-03, -2.37834505e-02, -1.88593677e-02, -5.43244237e-03,
#        -5.08740509e-03,  1.94909687e-03, -1.67728150e-02, -3.20247020e-02,
#        -3.55215328e-02, -3.06915232e-02, -1.46371762e-02, -1.78171048e-02,
#        -2.25141396e-02, -1.48176624e-02, -1.77018862e-02,  2.07438590e-02,
#         6.08906703e-04,  5.85902898e-03, -4.37965408e-03, -5.56533844e-03,
#        -1.38247288e-02,  8.37980275e-03,  1.48234684e-02, -6.57330544e-03,
#        -2.99890915e-03, -2.49487621e-03, -4.83896610e-03,  1.63775580e-02,
#        -9.97713943e-03, -1.50983456e-02,  4.71740377e-02,  7.91836034e-03,
#        -5.13163314e-02,  2.91106341e-02, -8.95878232e-03, -3.13464784e-04,
#        -3.23359195e-03, -2.46168511e-02, -2.32870506e-02, -6.94279272e-03,
#         8.18169324e-02,  3.22062756e-02,  1.71863580e-02, -1.31103971e-02,
#        -4.64241312e-03,  1.31514042e-02,  1.19330958e-03, -6.79372296e-03,
#        -1.74791423e-04, -1.93683129e-02, -4.99658415e-03, -1.25711450e-02,
#        -1.15750596e-02,  1.64240807e-02, -2.04343987e-02, -5.42118363e-03])

# %% [markdown]
# This is a Numpy array, so converted to a data frame in Pandas so it's easier to work with.

# %%
predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)

# %%
predictions
# Out:
#        predictions
# 630       0.013567
# 631      -0.013756
# 632       0.002414
# 633      -0.004421
# 634       0.010734
# ...            ...
# 13897    -0.012571
# 13898    -0.011575
# 13899     0.016424
# 13900    -0.020434
# 13901    -0.005421
#
# [540 rows x 1 columns]

# %% [markdown]
# Comparing actual values with forecasts, combining "Player", "Share" and concatenating with current forecasts.

# %%
combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)

# %%
combination
# Out:
#                        Player  Share  predictions
# 630              Aaron Gordon    0.0     0.013567
# 631             Austin Rivers    0.0    -0.013756
# 632                   Bol Bol    0.0     0.002414
# 633          Facundo Campazzo    0.0    -0.004421
# 634          Greg Whittington    0.0     0.010734
# ...                       ...    ...          ...
# 13897             Patty Mills    0.0    -0.012571
# 13898  Quinndary Weatherspoon    0.0    -0.011575
# 13899                Rudy Gay    0.0     0.016424
# 13900               Tre Jones    0.0    -0.020434
# 13901              Trey Lyles    0.0    -0.005421
#
# [540 rows x 3 columns]

# %% [markdown]
# Adjusting dataframe to only see players who actually won the MVP.

# %%
combination.sort_values("Share", ascending=False).head(10)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.154307
# 8624             Joel Embiid  0.580     0.162713
# 3651           Stephen Curry  0.449     0.142386
# 9907   Giannis Antetokounmpo  0.345     0.207436
# 1389              Chris Paul  0.138     0.072294
# 10997            Luka Dončić  0.042     0.151430
# 7464          Damian Lillard  0.038     0.116303
# 3536           Julius Randle  0.020     0.088878
# 3531            Derrick Rose  0.010     0.033000
# 11358            Rudy Gobert  0.008     0.095349

# %% [markdown]
# * Indentifying an error metric
#
# Basically this functions equation value take the actual values and the predicted values of an average error metric.

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(combination["Share"], combination["predictions"])
# Out:
# 0.0026668954567103916

# %% [markdown]
# But in this case it's not important because I don't need the actual values and 525 of the values are actually just zero because these players didn't get any MVP votes.
# So in this case this error metric doesn't make sense, because I'm just looking for the top five and best players in the ranking.

# %%
combination["Share"].value_counts()
# Out:
# 0.000    525
# 0.001      3
# 0.961      1
# 0.138      1
# 0.010      1
# 0.020      1
# 0.449      1
# 0.005      1
# 0.038      1
# 0.003      1
# 0.580      1
# 0.345      1
# 0.042      1
# 0.008      1
# Name: Share, dtype: int64

# %%
actual = combination.sort_values("Share", ascending=False)
predicted = combination.sort_values("predictions", ascending=False)
actual["Rk"] = list(range(1,actual.shape[0]+1))
predicted["Predicted_Rk"] = list(range(1,predicted.shape[0]+1))

# %%
combination.head(10)
# Out:
#                  Player  Share  predictions
# 630        Aaron Gordon    0.0     0.013567
# 631       Austin Rivers    0.0    -0.013756
# 632             Bol Bol    0.0     0.002414
# 633    Facundo Campazzo    0.0    -0.004421
# 634    Greg Whittington    0.0     0.010734
# 635      JaMychal Green    0.0    -0.004239
# 636        JaVale McGee    0.0     0.013357
# 637        Jamal Murray    0.0     0.042044
# 638       Markus Howard    0.0    -0.001333
# 639  Michael Porter Jr.    0.0     0.054226

# %%
actual.merge(predicted, on="Player").head(5)
# Out:
#                   Player  Share_x  predictions_x  Rk  Share_y  predictions_y  \
# 0           Nikola Jokić    0.961       0.154307   1    0.961       0.154307
# 1            Joel Embiid    0.580       0.162713   2    0.580       0.162713
# 2          Stephen Curry    0.449       0.142386   3    0.449       0.142386
# 3  Giannis Antetokounmpo    0.345       0.207436   4    0.345       0.207436
# 4             Chris Paul    0.138       0.072294   5    0.138       0.072294
#
#    Predicted_Rk
# 0             3
# 1             2
# 2             6
# 3             1
# 4            33

# %% [markdown]
# There are large discrepancies in the difference between the predicted rating and the actual rating.
# It uses the error metric called average precision, it is not used much for regression ML because it deals with classification

# %% [markdown]
# Trying to find out the top five players in MPV VOTING and how far you need to go in predictions to find them, so following the "Predicted_RK" column, Nikola Jokic needs to go down 3 predictions, Joel Embiid needs to go down 2, Stephen Curry needs to go down 6 and so on against.
# So, the logic would be to go through all the prediction lines and if the player in this line is in the top five we will give a credit of 1 for finding them, and if we don't find them a scene counter will be incremented.

# %%
def find_ap(combination):
    actual = combination.sort_values("Share", ascending=False).head(5)
    predicted = combination.sort_values("predictions", ascending=False)
    ps = []
    found = 0
    seen = 1
    for index,row in predicted.iterrows():
        if row["Player"] in actual["Player"].values:
            found += 1
            ps.append(found / seen)
        seen += 1

    return sum(ps) / len(ps)

# %%
find_ap(combination)
# Out:
# 0.7636363636363636

# %% [markdown]
# * Implementing backtesting to predict each year

# %% [markdown]
# So now there is a way to find the error.
# When running the algorithm for all years, it can be seen that it only has predictions for one year. A principle called back_testing is used to make predictions for most years.

# %%
years = list(range(1991,2022))

# %% [markdown]
# Training and test set: before 1997 is training set and 1997 test set

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors], train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps) / len(aps)
# Out:
# 0.7112884360789578

# %%
def add_ranks(predictions):
    predictions = predictions.sort_values("predictions", ascending=False)
    predictions["Predicted_Rk"] = list(range(1,predictions.shape[0]+1))
    predictions = predictions.sort_values("Share", ascending=False)
    predictions["Rk"] = list(range(1,predictions.shape[0]+1))
    predictions["Diff"] = (predictions["Rk"] - predictions["Predicted_Rk"])
    return predictions

# %%
add_ranks(all_predictions[1])
# Out:
#                 Player  Share  predictions  Predicted_Rk   Rk  Diff
# 1600       Karl Malone  0.857     0.192318             2    1    -1
# 10524   Michael Jordan  0.832     0.167629             3    2    -1
# 908         Grant Hill  0.327     0.128646             6    3    -3
# 4682      Tim Hardaway  0.207     0.059984            20    4   -16
# 8248         Glen Rice  0.117     0.033110            53    5   -48
# ...                ...    ...          ...           ...  ...   ...
# 10136   Horacio Llamas  0.000     0.010171           156  437   281
# 3576     Ennis Whatley  0.000     0.010250           155  438   283
# 10594  Kevin Salvadori  0.000     0.010553           154  439   285
# 1138    Aaron Williams  0.000     0.010594           153  440   287
# 6792     Melvin Booker  0.000    -0.055185           441  441     0
#
# [441 rows x 6 columns]

# %%
def backtest(stats, model, years, predictors):
    aps = []
    all_predictions = []
    for year in years:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = model.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps) / len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7112884360789578

# %%
all_predictions[all_predictions["Rk"] < 5].sort_values("Diff").head(10)
# Out:
#                 Player  Share  predictions  Predicted_Rk  Rk  Diff
# 1224        Jason Kidd  0.712     0.028209            52   2   -50
# 5175        Steve Nash  0.839     0.034100            45   1   -44
# 8516   Peja Stojaković  0.228     0.036269            38   4   -34
# 12726      Joakim Noah  0.258     0.046968            37   4   -33
# 5193        Steve Nash  0.739     0.054128            34   1   -33
# 5208        Steve Nash  0.785     0.074421            21   2   -19
# 4682      Tim Hardaway  0.207     0.059984            20   4   -16
# 937      Allen Iverson  0.270     0.072120            14   4   -10
# 6746       Kobe Bryant  0.291     0.078014            14   4   -10
# 1157       Gary Payton  0.372     0.076708            13   3   -10

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.070002  eFG%
# 18  0.035041   DRB
# 29  0.027126  W/L%
# 17  0.021610   ORB
# 10  0.016945    2P
# 21  0.011635   STL
# 15  0.011351   FTA
# 22  0.011234   BLK
# 20  0.007456   AST
# 25  0.005893   PTS
# 4   0.005694    FG
# 5   0.005516   FGA
# 7   0.004569    3P
# 12  0.004083   2P%
# 0   0.000321   Age
# 30  0.000270    GB
# 27  0.000098     W
# 1   0.000092     G
# 2  -0.000006    GS
# 26 -0.000184  Year
# 32 -0.000219  PA/G
# 28 -0.000295     L
# 33 -0.000521   SRS
# 31 -0.000556  PS/G
# 24 -0.002634    PF
# 3  -0.004150    MP
# 16 -0.004575   FT%
# 14 -0.006585    FT
# 23 -0.009696   TOV
# 9  -0.009822   3P%
# 8  -0.010394   3PA
# 11 -0.017318   2PA
# 19 -0.027506   TRB
# 6  -0.135025   FG%

# %%
stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())

# %%
stats[["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]] = stat_ratios[["PTS", "AST", "STL", "BLK", "3P"]]

# %%
predictors += ["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7208380973034985

# %% [markdown]
# * Diagnosing model performance

# %%
all_predictions[all_predictions["Rk"] <= 5].sort_values("Diff").head(10)
# Out:
#                  Player  Share  predictions  Predicted_Rk  Rk  Diff
# 1224         Jason Kidd  0.712     0.025769            56   2   -54
# 12726       Joakim Noah  0.258     0.038848            45   4   -41
# 5175         Steve Nash  0.839     0.035739            41   1   -40
# 8248          Glen Rice  0.117     0.044268            44   5   -39
# 8516    Peja Stojaković  0.228     0.040912            33   4   -29
# 1389         Chris Paul  0.138     0.063156            33   5   -28
# 3657   Chauncey Billups  0.344     0.054745            28   5   -23
# 5193         Steve Nash  0.739     0.062935            22   1   -21
# 4682       Tim Hardaway  0.207     0.062711            25   4   -21
# 10513    Scottie Pippen  0.200     0.065472            21   5   -16

# %%
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0      1
# 22  0.133731    BLK
# 21  0.053429    STL
# 34  0.049902  PTS_R
# 13  0.047624   eFG%
# 18  0.036060    DRB
# 29  0.029260   W/L%
# 35  0.028368  AST_R
# 17  0.022343    ORB
# 10  0.019677     2P
# 15  0.011051    FTA
# 7   0.009136     3P
# 4   0.005830     FG
# 5   0.004974    FGA
# 0   0.000315    Age
# 30  0.000243     GB
# 27  0.000176      W
# 1   0.000093      G
# 25  0.000081    PTS
# 2  -0.000002     GS
# 26 -0.000083   Year
# 31 -0.000152   PS/G
# 28 -0.000180      L
# 32 -0.000311   PA/G
# 33 -0.000851    SRS
# 12 -0.001756    2P%
# 24 -0.002298     PF
# 38 -0.003084   3P_R
# 3  -0.004251     MP
# 16 -0.004272    FT%
# 14 -0.006614     FT
# 9  -0.007261    3P%
# 20 -0.007595    AST
# 8  -0.009258    3PA
# 23 -0.010394    TOV
# 11 -0.018350    2PA
# 36 -0.027336  STL_R
# 19 -0.028326    TRB
# 37 -0.051758  BLK_R
# 6  -0.108629    FG%

# %% [markdown]
# * Adding more predictors

# %%
stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())

# %%
stat_ratios
# Out:
#             PTS       AST       STL       BLK        3P  Year
# 0      1.013334  0.420714  0.961127  0.673469  0.508587   1.0
# 1      1.614653  1.028412  1.647646  0.673469  4.577279   1.0
# 2      0.311795  0.093492  0.274608  1.571429  0.000000   1.0
# 3      0.200440  0.186984  0.274608  0.000000  0.000000   1.0
# 4      2.383005  1.636110  1.784950  0.897959  1.525760   1.0
# ...         ...       ...       ...       ...       ...   ...
# 14087  0.735752  0.819562  0.479763  1.528302  0.650951   1.0
# 14088  0.071202  0.000000  0.000000  0.000000  0.130190   1.0
# 14089  1.281633  0.601012  1.119447  2.547170  0.520761   1.0
# 14090  0.474679  0.218550  0.319842  1.273585  0.650951   1.0
# 14091  1.008693  0.655649  1.119447  0.509434  2.343424   1.0
#
# [14092 rows x 6 columns]

# %%
stats[["PTS_T", "AST_R", "STL_R", "BLK_R", "3P_R"]] = stat_ratios[["PTS", "AST", "STL", "BLK", "3P"]]

# %%
stats.head()
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...   GB  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  5.0
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  5.0
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  5.0
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  5.0
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  5.0
#
#     PS/G  PA/G   SRS     PTS_R     AST_R     STL_R     BLK_R      3P_R  \
# 0  106.3  99.6  6.73  1.013334  0.420714  0.961127  0.673469  0.508587
# 1  106.3  99.6  6.73  1.614653  1.028412  1.647646  0.673469  4.577279
# 2  106.3  99.6  6.73  0.311795  0.093492  0.274608  1.571429  0.000000
# 3  106.3  99.6  6.73  0.200440  0.186984  0.274608  0.000000  0.000000
# 4  106.3  99.6  6.73  2.383005  1.636110  1.784950  0.897959  1.525760
#
#       PTS_T
# 0  1.013334
# 1  1.614653
# 2  0.311795
# 3  0.200440
# 4  2.383005
#
# [5 rows x 47 columns]

# %%
predictors += ["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7208380973034985

# %%
stats["Pos"].unique
# Out:
# <bound method Series.unique of 0        PF
# 1        SG
# 2        PF
# 3        PF
# 4        SF
#          ..
# 14087    PF
# 14088    PF
# 14089    PF
# 14090     C
# 14091    SG
# Name: Pos, Length: 14092, dtype: object>

# %%
stats["NPos"] = stats["Pos"].astype("category").cat.codes
stats["NTm"] = stats["Tm"].astype("category").cat.codes

# %%
stats.head(5)
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  PA/G  \
# 0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...  99.6
# 1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...  99.6
# 2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...  99.6
# 3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...  99.6
# 4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...  99.6
#
#     SRS     PTS_R     AST_R     STL_R     BLK_R      3P_R     PTS_T  NPos  NTm
# 0  6.73  1.013334  0.420714  0.961127  0.673469  0.508587  1.013334     2   15
# 1  6.73  1.614653  1.028412  1.647646  0.673469  4.577279  1.614653    12   15
# 2  6.73  0.311795  0.093492  0.274608  1.571429  0.000000  0.311795     2   15
# 3  6.73  0.200440  0.186984  0.274608  0.000000  0.000000  0.200440     2   15
# 4  6.73  2.383005  1.636110  1.784950  0.897959  1.525760  2.383005     8   15
#
# [5 rows x 49 columns]

# %% [markdown]
# * Using a random forest model

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=50, random_state=1, min_samples_split=5)

mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors + ["NPos", "NTm"])

# %%
mean_ap
# Out:
# 0.8387324929971989
